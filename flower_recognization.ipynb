# %%
import os
import cv2
import numpy as np

#Encoding and Split data into Train/Test Sets
from sklearn.preprocessing import LabelEncoder
from tensorflow.keras.utils import to_categorical
from sklearn.model_selection import train_test_split

#Tensorflow Keras CNN Model
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Dropout, Flatten, Activation, Conv2D, MaxPooling2D
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.optimizers import Adam,SGD,Adagrad,Adadelta,RMSprop

#Plot Images
import matplotlib.pyplot as plt


folder_dir = 'flowers'

# %%
data = []
label = []

SIZE = 128 #Crop the image to 128x128

for folder in os.listdir(folder_dir):
    for file in os.listdir(os.path.join(folder_dir, folder)):
        if file.endswith("jpg"):
            label.append(folder)
            img = cv2.imread(os.path.join(folder_dir, folder, file))
            img_rgb = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
            im = cv2.resize(img_rgb, (SIZE,SIZE))
            data.append(im)
        else:
            continue

# %%
data_arr = np.array(data)
label_arr = np.array(label)

# %%
encoder = LabelEncoder()
y = encoder.fit_transform(label_arr)
y = to_categorical(y,5)
X = data_arr/255

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.20, random_state=10)

# %%
model = Sequential()
model.add(Conv2D(filters = 64, kernel_size = (3,3),padding = 'Same',activation ='relu', input_shape = (SIZE,SIZE,3)))
model.add(MaxPooling2D(pool_size=(2,2)))

model.add(Conv2D(filters = 128, kernel_size = (3,3),padding = 'Same',activation ='relu'))
model.add(Conv2D(filters = 128, kernel_size = (3,3),padding = 'Same',activation ='relu'))
model.add(Conv2D(filters = 128, kernel_size = (3,3),padding = 'Same',activation ='relu'))
model.add(MaxPooling2D(pool_size=(2,2)))

model.add(Flatten())
model.add(Dense(128, activation='relu'))
model.add(Dense(64, activation='relu'))
model.add(Dropout(rate=0.5))
model.add(Dense(5, activation = "softmax"))

# %%
datagen = ImageDataGenerator(
        rotation_range=20,
        zoom_range = 0.20,
        width_shift_range=0.3,
        height_shift_range=0.3,
        horizontal_flip=True,
        vertical_flip=True)

datagen.fit(X_train)

# %%
model.compile(optimizer=Adam(lr=0.0001),loss='categorical_crossentropy',metrics=['accuracy'])
batch_size=32
epochs=64
history = model.fit_generator(datagen.flow(X_train,y_train, batch_size=batch_size),
                              epochs = epochs,
                              validation_data = (X_test,y_test),
                              verbose = 1)
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\tensorflow\python\keras\engine\training.py:1844: UserWarning: `Model.fit_generator` is deprecated and will be removed in a future version. Please use `Model.fit`, which supports generators.
#   warnings.warn('`Model.fit_generator` is deprecated and '
# Epoch 1/64
# 109/109 [==============================] - 396s 3s/step - loss: 1.5682 - accuracy: 0.2673 - val_loss: 1.2721 - val_accuracy: 0.4890
# Epoch 2/64
# 109/109 [==============================] - 381s 4s/step - loss: 1.3556 - accuracy: 0.3955 - val_loss: 1.3080 - val_accuracy: 0.4220
# Epoch 3/64
# 109/109 [==============================] - 375s 3s/step - loss: 1.3004 - accuracy: 0.4470 - val_loss: 1.1467 - val_accuracy: 0.5503
# Epoch 4/64
# 109/109 [==============================] - 349s 3s/step - loss: 1.2265 - accuracy: 0.5026 - val_loss: 1.1135 - val_accuracy: 0.5445
# Epoch 5/64
# 109/109 [==============================] - 346s 3s/step - loss: 1.1785 - accuracy: 0.5218 - val_loss: 1.0976 - val_accuracy: 0.5249
# Epoch 6/64
# 109/109 [==============================] - 331s 3s/step - loss: 1.1376 - accuracy: 0.5353 - val_loss: 1.0142 - val_accuracy: 0.5919
# Epoch 7/64
# 109/109 [==============================] - 329s 3s/step - loss: 1.1055 - accuracy: 0.5646 - val_loss: 1.0380 - val_accuracy: 0.5746
# Epoch 8/64
# 109/109 [==============================] - 341s 3s/step - loss: 1.1280 - accuracy: 0.5554 - val_loss: 1.0297 - val_accuracy: 0.5792
# Epoch 9/64
# 109/109 [==============================] - 342s 3s/step - loss: 1.0620 - accuracy: 0.5915 - val_loss: 0.9728 - val_accuracy: 0.6231
# Epoch 10/64
# 109/109 [==============================] - 398s 4s/step - loss: 1.0505 - accuracy: 0.5937 - val_loss: 0.9461 - val_accuracy: 0.6301
# Epoch 11/64
# 109/109 [==============================] - 323s 3s/step - loss: 1.0291 - accuracy: 0.6017 - val_loss: 1.0094 - val_accuracy: 0.5873
# Epoch 12/64
# 109/109 [==============================] - 335s 3s/step - loss: 0.9784 - accuracy: 0.6204 - val_loss: 0.9358 - val_accuracy: 0.6150
# Epoch 13/64
# 109/109 [==============================] - 337s 3s/step - loss: 0.9602 - accuracy: 0.6306 - val_loss: 0.8851 - val_accuracy: 0.6486
# Epoch 14/64
# 109/109 [==============================] - 407s 4s/step - loss: 0.9690 - accuracy: 0.6262 - val_loss: 0.8699 - val_accuracy: 0.6497
# Epoch 15/64
# 109/109 [==============================] - 330s 3s/step - loss: 0.9399 - accuracy: 0.6228 - val_loss: 0.8185 - val_accuracy: 0.6821
# Epoch 16/64
# 109/109 [==============================] - 324s 3s/step - loss: 0.9072 - accuracy: 0.6586 - val_loss: 0.8968 - val_accuracy: 0.6439
# Epoch 17/64
# 109/109 [==============================] - 318s 3s/step - loss: 0.9347 - accuracy: 0.6416 - val_loss: 0.8158 - val_accuracy: 0.6913
# Epoch 18/64
# 109/109 [==============================] - 318s 3s/step - loss: 0.9500 - accuracy: 0.6390 - val_loss: 0.7951 - val_accuracy: 0.6936
# Epoch 19/64
# 109/109 [==============================] - 315s 3s/step - loss: 0.8943 - accuracy: 0.6554 - val_loss: 0.8609 - val_accuracy: 0.6671
# Epoch 20/64
# 109/109 [==============================] - 311s 3s/step - loss: 0.8767 - accuracy: 0.6655 - val_loss: 0.7785 - val_accuracy: 0.6832
# Epoch 21/64
# 109/109 [==============================] - 326s 3s/step - loss: 0.8545 - accuracy: 0.6784 - val_loss: 0.7420 - val_accuracy: 0.7098
# Epoch 22/64
# 109/109 [==============================] - 331s 3s/step - loss: 0.8566 - accuracy: 0.6814 - val_loss: 0.7477 - val_accuracy: 0.7017
# Epoch 23/64
# 109/109 [==============================] - 328s 3s/step - loss: 0.8700 - accuracy: 0.6803 - val_loss: 0.7862 - val_accuracy: 0.6902
# Epoch 24/64
# 109/109 [==============================] - 319s 3s/step - loss: 0.8312 - accuracy: 0.6856 - val_loss: 0.7489 - val_accuracy: 0.7168
# Epoch 25/64
# 109/109 [==============================] - 319s 3s/step - loss: 0.8539 - accuracy: 0.6666 - val_loss: 0.7169 - val_accuracy: 0.7353
# Epoch 26/64
# 109/109 [==============================] - 342s 3s/step - loss: 0.8171 - accuracy: 0.6956 - val_loss: 0.7297 - val_accuracy: 0.7145
# Epoch 27/64
# 109/109 [==============================] - 374s 3s/step - loss: 0.7893 - accuracy: 0.7062 - val_loss: 0.7666 - val_accuracy: 0.7121
# Epoch 28/64
# 109/109 [==============================] - 366s 3s/step - loss: 0.8084 - accuracy: 0.7025 - val_loss: 0.7416 - val_accuracy: 0.7029
# Epoch 29/64
# 109/109 [==============================] - 339s 3s/step - loss: 0.8003 - accuracy: 0.7077 - val_loss: 0.7316 - val_accuracy: 0.7087
# Epoch 30/64
# 109/109 [==============================] - 336s 3s/step - loss: 0.7940 - accuracy: 0.6855 - val_loss: 0.7250 - val_accuracy: 0.7133
# Epoch 31/64
# 109/109 [==============================] - 321s 3s/step - loss: 0.7925 - accuracy: 0.7057 - val_loss: 0.6983 - val_accuracy: 0.7376
# Epoch 32/64
# 109/109 [==============================] - 320s 3s/step - loss: 0.7667 - accuracy: 0.7213 - val_loss: 0.6869 - val_accuracy: 0.7410
# Epoch 33/64
# 109/109 [==============================] - 318s 3s/step - loss: 0.8152 - accuracy: 0.6945 - val_loss: 0.7280 - val_accuracy: 0.7052
# Epoch 34/64
# 109/109 [==============================] - 317s 3s/step - loss: 0.7830 - accuracy: 0.7105 - val_loss: 0.6819 - val_accuracy: 0.7387
# Epoch 35/64
# 109/109 [==============================] - 314s 3s/step - loss: 0.7499 - accuracy: 0.7191 - val_loss: 0.7674 - val_accuracy: 0.6855
# Epoch 36/64
# 109/109 [==============================] - 310s 3s/step - loss: 0.7548 - accuracy: 0.7262 - val_loss: 0.6685 - val_accuracy: 0.7503
# Epoch 37/64
# 109/109 [==============================] - 311s 3s/step - loss: 0.7353 - accuracy: 0.7353 - val_loss: 0.6847 - val_accuracy: 0.7422
# Epoch 38/64
# 109/109 [==============================] - 346s 3s/step - loss: 0.7507 - accuracy: 0.7194 - val_loss: 0.7077 - val_accuracy: 0.7295
# Epoch 39/64
# 109/109 [==============================] - 316s 3s/step - loss: 0.7824 - accuracy: 0.6998 - val_loss: 0.6900 - val_accuracy: 0.7364
# Epoch 40/64
# 109/109 [==============================] - 315s 3s/step - loss: 0.7491 - accuracy: 0.7194 - val_loss: 0.6542 - val_accuracy: 0.7584
# Epoch 41/64
# 109/109 [==============================] - 315s 3s/step - loss: 0.7648 - accuracy: 0.7340 - val_loss: 0.6813 - val_accuracy: 0.7480
# Epoch 42/64
# 109/109 [==============================] - 316s 3s/step - loss: 0.7447 - accuracy: 0.7099 - val_loss: 0.6480 - val_accuracy: 0.7572
# Epoch 43/64
# 109/109 [==============================] - 312s 3s/step - loss: 0.7276 - accuracy: 0.7204 - val_loss: 0.6743 - val_accuracy: 0.7480
# Epoch 44/64
# 109/109 [==============================] - 312s 3s/step - loss: 0.6993 - accuracy: 0.7314 - val_loss: 0.6994 - val_accuracy: 0.7353
# Epoch 45/64
# 109/109 [==============================] - 315s 3s/step - loss: 0.7079 - accuracy: 0.7397 - val_loss: 0.6905 - val_accuracy: 0.7353
# Epoch 46/64
# 109/109 [==============================] - 310s 3s/step - loss: 0.6795 - accuracy: 0.7369 - val_loss: 0.6561 - val_accuracy: 0.7561
# Epoch 47/64
# 109/109 [==============================] - 310s 3s/step - loss: 0.6914 - accuracy: 0.7394 - val_loss: 0.6942 - val_accuracy: 0.7283
# Epoch 48/64
# 109/109 [==============================] - 313s 3s/step - loss: 0.7342 - accuracy: 0.7265 - val_loss: 0.6978 - val_accuracy: 0.7156
# Epoch 49/64
# 109/109 [==============================] - 309s 3s/step - loss: 0.7025 - accuracy: 0.7441 - val_loss: 0.6388 - val_accuracy: 0.7618
# Epoch 50/64
# 109/109 [==============================] - 305s 3s/step - loss: 0.6883 - accuracy: 0.7414 - val_loss: 0.6339 - val_accuracy: 0.7630
# Epoch 51/64
# 109/109 [==============================] - 306s 3s/step - loss: 0.6712 - accuracy: 0.7429 - val_loss: 0.6176 - val_accuracy: 0.7630
# Epoch 52/64
# 109/109 [==============================] - 305s 3s/step - loss: 0.6422 - accuracy: 0.7622 - val_loss: 0.6334 - val_accuracy: 0.7618
# Epoch 53/64
# 109/109 [==============================] - 307s 3s/step - loss: 0.6484 - accuracy: 0.7601 - val_loss: 0.6080 - val_accuracy: 0.7711
# Epoch 54/64
# 109/109 [==============================] - 304s 3s/step - loss: 0.6711 - accuracy: 0.7565 - val_loss: 0.6447 - val_accuracy: 0.7538
# Epoch 55/64
# 109/109 [==============================] - 363s 3s/step - loss: 0.6466 - accuracy: 0.7615 - val_loss: 0.6382 - val_accuracy: 0.7514
# Epoch 56/64
# 109/109 [==============================] - 389s 4s/step - loss: 0.6533 - accuracy: 0.7521 - val_loss: 0.6038 - val_accuracy: 0.7803
# Epoch 57/64
# 109/109 [==============================] - 327s 3s/step - loss: 0.6553 - accuracy: 0.7578 - val_loss: 0.6451 - val_accuracy: 0.7630
# Epoch 58/64
# 109/109 [==============================] - 310s 3s/step - loss: 0.6751 - accuracy: 0.7404 - val_loss: 0.6220 - val_accuracy: 0.7572
# Epoch 59/64
# 109/109 [==============================] - 307s 3s/step - loss: 0.6504 - accuracy: 0.7603 - val_loss: 0.6304 - val_accuracy: 0.7595
# Epoch 60/64
# 109/109 [==============================] - 309s 3s/step - loss: 0.6145 - accuracy: 0.7670 - val_loss: 0.5992 - val_accuracy: 0.7676
# Epoch 61/64
# 109/109 [==============================] - 303s 3s/step - loss: 0.6305 - accuracy: 0.7538 - val_loss: 0.6257 - val_accuracy: 0.7538
# Epoch 62/64
# 109/109 [==============================] - 305s 3s/step - loss: 0.6187 - accuracy: 0.7672 - val_loss: 0.6517 - val_accuracy: 0.7503
# Epoch 63/64
# 109/109 [==============================] - 304s 3s/step - loss: 0.5951 - accuracy: 0.7685 - val_loss: 0.6995 - val_accuracy: 0.7214
# Epoch 64/64
# 109/109 [==============================] - 305s 3s/step - loss: 0.6051 - accuracy: 0.7769 - val_loss: 0.6166 - val_accuracy: 0.7711

# %%
categories = np.sort(os.listdir(folder_dir))
fig, ax = plt.subplots(6,6, figsize=(25, 40))

for i in range(6):
    for j in range(6):
        k = int(np.random.random_sample() * len(X_test))
        if(categories[np.argmax(y_test[k])] == categories[np.argmax(model.predict(X_test)[k])]):
            ax[i,j].set_title("TRUE: " + categories[np.argmax(y_test[k])], color='green')
            ax[i,j].set_xlabel("PREDICTED: " + categories[np.argmax(model.predict(X_test)[k])], color='green')
            ax[i,j].imshow(np.array(X_test)[k].reshape(SIZE, SIZE, 3), cmap='gray')
        else:
            ax[i,j].set_title("TRUE: " + categories[np.argmax(y_test[k])], color='red')
            ax[i,j].set_xlabel("PREDICTED: " + categories[np.argmax(model.predict(X_test)[k])], color='red')
            ax[i,j].imshow(np.array(X_test)[k].reshape(SIZE, SIZE, 3), cmap='gray')
